# %%
# !pip install opencv-python

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\1.jpg')
display(image.shape)
# Out:
# (408, 612, 3)

# %%
plt.imshow(image)
plt.show()

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\11.jpg')
display(image.shape)
# Out:
# (164, 308, 3)

# %%
plt.imshow(image)
plt.show()

# %%
print(image)
# Out:
# [[[233 235 235]
#   [243 245 245]
#   [250 252 252]
#   ...
#   [182 169 143]
#   [178 165 139]
#   [176 163 137]]
#
#  [[233 235 235]
#   [243 245 245]
#   [250 252 252]
#   ...
#   [184 171 145]
#   [180 167 141]
#   [179 166 140]]
#
#  [[233 235 235]
#   [243 245 245]
#   [250 252 252]
#   ...
#   [187 174 148]
#   [183 170 144]
#   [181 168 142]]
#
#  ...
#
#  [[  1   1   1]
#   [  1   1   1]
#   [  1   1   1]
#   ...
#   [ 39  45  80]
#   [ 11  19  48]
#   [  8  18  42]]
#
#  [[  1   1   1]
#   [  1   1   1]
#   [  1   1   1]
#   ...
#   [ 35  40  73]
#   [ 10  16  45]
#   [ 10  17  42]]
#
#  [[  1   1   1]
#   [  1   1   1]
#   [  1   1   1]
#   ...
#   [ 29  34  67]
#   [  5  12  39]
#   [  8  16  39]]]

# %%
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
image_gray = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
cv2.imshow('',image_gray)
cv2.waitKey(0)
# Out:
# -1

# %%
display(image_gray.shape)
# Out:
# (408, 612)

# %% [markdown]
# # Detecting FACE

# %%
face_detector = cv2.CascadeClassifier('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Casscade\\haarcascade_frontalface_default.xml')
face_detector
# Out:
# < cv2.CascadeClassifier 000001EDAE2BFC90>

# %%
detections = face_detector.detectMultiScale(image_gray)
display(detections)
# Out:
# array([[310,  10,  66,  66],
#        [139, 105,  57,  57],
#        [ 87, 123,  57,  57],
#        [ 89, 301,  58,  58],
#        [479,  99,  64,  64],
#        [174,  55,  55,  55],
#        [131,  62,  55,  55],
#        [385,  59,  60,  60],
#        [247,  84,  55,  55],
#        [316,  33,  53,  53],
#        [ 35,  38,  56,  56]])

# %%
display(len(detections))
# Out:
# 11

# %%
x=310
y=10
w=66
h=66
cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,255),1)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %%
#Display all Detected face with Rectangle
for(x,y,w,h) in detections:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,255),5)
cv2.imshow('', image)
cv2.waitKey(0)
plt.show()

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\1.jpg')
display(image.shape)
image = cv2.resize(image,(800 , 600))
display(image.shape)
detections = face_detector.detectMultiScale(image)
display(detections)
# Out:
# (408, 612, 3)
# (600, 800, 3)
# array([[181, 159,  74,  74],
#        [115, 446,  80,  80],
#        [ 44,  59,  74,  74],
#        [625, 150,  86,  86],
#        [112, 185,  76,  76],
#        [415,  54,  65,  65],
#        [227,  84,  72,  72],
#        [502,  91,  81,  81],
#        [724, 210,  72,  72],
#        [319, 128,  71,  71]])

# %%
for (x , y , w , h) in detections:
    cv2.rectangle(image,(x,y),(x+w,y+h) , (0 , 255 , 255) , 5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %% [markdown]
# # Parameter

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\1.jpg')
image = cv2.resize(image,(800,600))
image_gray=cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image , scaleFactor = 1.16 )
display(detections)
for(x, y , w , h) in detections:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),5)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[182, 159,  73,  73],
#        [623, 149,  86,  86],
#        [112, 446,  82,  82],
#        [ 42,  58,  76,  76],
#        [413,  53,  71,  71],
#        [112, 185,  77,  77],
#        [225,  84,  74,  74],
#        [502,  91,  81,  81],
#        [724, 212,  71,  71],
#        [319, 127,  73,  73]])

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\11.jpg')
image_gray=cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image_gray , scaleFactor = 1.02 , minNeighbors = 7)
display(detections)
for(x,y,w,h) in detections:
    print(w,h)
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[128,  43,  39,  39],
#        [156,  13,  30,  30],
#        [241,  53,  40,  40],
#        [ 96,  15,  39,  39],
#        [213,  29,  31,  31],
#        [ 45,  39,  53,  53]])
# 39 39
# 30 30
# 40 40
# 39 39
# 31 31
# 53 53

# %% [markdown]
# # Using Paramter - minSize and maxSize

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\11.jpg')
image_gray = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image , scaleFactor = 1.02 , minNeighbors = 7 , minSize = (20 , 20) , maxSize = (100 , 100))
display(detections)

for(x , y , w , h) in detections:
    print(w,h)
    cv2.rectangle(image , (x,y), (x+w , y+h), (0,255,0) , 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[128,  43,  39,  39],
#        [156,  13,  30,  30],
#        [241,  53,  40,  40],
#        [ 96,  15,  39,  39],
#        [213,  29,  31,  31],
#        [ 45,  39,  53,  53]])
# 39 39
# 30 30
# 40 40
# 39 39
# 31 31
# 53 53

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\1.jpg')
image_gray = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
detections = face_detector.detectMultiScale(image , scaleFactor = 1.02 , minNeighbors = 7 , minSize = (20 , 20) , maxSize = (100 , 100))
display(detections)

for(x , y , w , h) in detections:
    print(w,h)
    cv2.rectangle(image , (x,y), (x+w , y+h), (0,255,0) , 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# array([[310,  11,  64,  64],
#        [139, 105,  57,  57],
#        [ 86, 124,  58,  58],
#        [479, 100,  63,  63],
#        [ 89, 301,  58,  58],
#        [316,  33,  53,  53],
#        [ 34,  37,  57,  57],
#        [556, 142,  51,  51],
#        [174,  55,  55,  55],
#        [132,  63,  53,  53],
#        [386,  61,  57,  57],
#        [245,  84,  54,  54]])
# 64 64
# 57 57
# 58 58
# 63 63
# 58 58
# 53 53
# 57 57
# 51 51
# 55 55
# 53 53
# 57 57
# 54 54

# %% [markdown]
# # EYE DETECTOR

# %%
face_detector = cv2.CascadeClassifier('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Casscade\\haarcascade_frontalface_default.xml')
display(face_detector)

eye_detector = cv2.CascadeClassifier('C:\\Deepanshi\Machine Learning\\Project 1 Face Detection\\Casscade\\haarcascade_eye.xml')
display(eye_detector)
# Out:
# < cv2.CascadeClassifier 000001EDB833BF90>
# < cv2.CascadeClassifier 000001EDAE193ED0>

# %% [markdown]
# #Use Both Eye detection and Face Detection

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\1.jpg')
display(image.shape)
# Out:
# (408, 612, 3)

# %%
image = cv2.resize (image ,(1600 , 1000))
print(image.shape)
face_detections = face_detector.detectMultiScale(image , scaleFactor = 1.3 , minSize = (30 , 30))
for (x , y , w , h) in face_detections:
    cv2.rectangle(image,(x,y) , (x+w , y+h),(0,255,0),2)
eye_detections = eye_detector.detectMultiScale(image , scaleFactor = 1.1, minNeighbors = 10 , maxSize = (60 , 60))
for (x , y , w , h) in face_detections:
    cv2.rectangle(image,(x,y) , (x+w , y+h),(0,0,255),2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (1000, 1600, 3)

# %% [markdown]
# # Clock Detections

# %%
#load The .xml File

clock_detector = cv2.CascadeClassifier('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Casscade\\clocks.xml')
display(clock_detector)

#Load Image
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\clockset.jpg')
display(image.shape)
cv2.imshow('' , image)
cv2.waitKey(0)
plt.show()
# Out:
# < cv2.CascadeClassifier 000002358967B8D0>
# (197, 255, 3)

# %%
detections = clock_detector.detectMultiScale(image , scaleFactor = 1.03 , minNeighbors = 1)
for (x , y , w , h) in detections:
    cv2.rectangle(image,(x,y),(x+w , y+h) , (0,255,0) , 2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %% [markdown]
# # Full Body Detector

# %%
#Load .xml File
full_detector = cv2.CascadeClassifier('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Casscade\\fullbody.xml')
display(full_detector)
# Out:
# < cv2.CascadeClassifier 000002358D817450>

# %%
#Load Image
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\full.jpg')
display(image.shape)

cv2.imshow('',image)
cv2.waitKey(0)
plt.show()
# Out:
# (280, 366, 3)

# %%
image_gray = cv2.cvtColor(image , cv2.COLOR_BGR2GRAY)
detections = full_detector.detectMultiScale(image_gray , scaleFactor = 1.03 , minNeighbors = 5 , minSize = (50,50))
for(x , y , w , h) in detections:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
cv2.imshow('',image)
cv2.waitKey(0)
plt.show()

# %% [markdown]
# # FACE DETECTION with HOG and DLIB

# %%
import dlib

# %%
image = cv2.imread('C:\\Deepanshi\\Machine Learning\\Project 1 Face Detection\\Data Set 1\\1.jpg')
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# #Creating the Model

# %%
face_detector_hog = dlib.get_frontal_face_detector()
detections = face_detector_hog(image , 1) # 1 is the Scale Factor

# %%
display(len(detections))
display(detections)
# Out:
# 8
# rectangles[[(141, 113) (193, 164)], [(247, 89) (290, 132)], [(89, 130) (141, 182)], [(37, 44) (89, 95)], [(180, 65) (223, 108)], [(481, 107) (533, 159)], [(389, 67) (440, 118)], [(314, 38) (366, 90)]]

# %%
print(detections[0])
print(detections[0].left())
print(detections[0].top())
print(detections[0].right())
print(detections[0].bottom())
cv2.rectangle(image , (detections[0].left() , detections[0].top()) , (detections[0].right() , detections[0].bottom()) , (0 , 255 , 255) , 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# [(141, 113) (193, 164)]
# 141
# 113
# 193
# 164
# -1

# %%
for face in detections:
    l , t , r , b = face.left() , face.top() , face.right() , face.bottom()
    cv2.rectangle(image , (l,t) , (r,b) , (0, 255,255) , 2)
cv2.imshow('',image)
cv2.waitKey(0)
# Out:
# -1
